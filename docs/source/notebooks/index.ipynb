# %% [markdown]
# # Welcome to diplotocus' documentation!
#
# <center><video width="700" height="394" autoplay muted playsinline><source src="../_static/logo.mp4" type="video/mp4"></video></center>
#
# **Diplotocus** is a python package designed to render animations of [matplotlib](https://matplotlib.org/) objects, in a *timeline* style.
#
# Here's a quick example of the syntax of diplotocus:

# %%
import diplotocus as dpl
import numpy as np

#We define our Sequence, the object that handles all animations on our figure
seq = dpl.Sequence(xlim=(0,6*np.pi),ylim=(-1,1))

#We generate data points
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

#We create a plot() object
p = dpl.plot(x=x,y=y)

#We draw its data points sequentially
p.draw(duration=100)
seq.animate(p)

#We wait 25 frames
seq.wait(duration=25)

#We unzoom and move the axis to (0,0)
az = dpl.axis_zoom(zoom=0.5,duration=50)
am = dpl.axis_move(end_pos=(0,0),duration=50)
seq.animate((az,am))

#We hide the plot
p.hide(duration=100)
seq.animate(p)

#We render our video
seq.save_video(path='../_static/demo.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/demo.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/demo.mp4?randId=6648" type="video/mp4">
#             </video>
