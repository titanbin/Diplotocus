# %% [markdown]
# # Examples
#
# This page contains examples of usages of **Diplotocus**.
#
# ::::{grid} 1 2 3 3
# :gutter: 2
#
# :::{grid-item-card}
# :link: examples/flag.html
# <video autoplay muted loop playsinline style="width: 100%; height: auto; display: block;">
#     <source src="../_static/examples/flag.mp4" type="video/mp4">
# </video>
# Flag
# :::
#
# :::{grid-item-card}
# :link: examples/flower.html
# <video autoplay muted loop playsinline style="width: 100%; height: auto; display: block;">
#     <source src="../_static/examples/flower.mp4" type="video/mp4">
# </video>
# Flower
# :::
#
# ::::

# %% [markdown]
# ```{toctree}
# :maxdepth: 1
# :hidden:
#
# examples/flag
# examples/flower
# ```
