# %% [markdown]
# # diplotocus.scatter

# %%
import diplotocus as dpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## diplotocus.scatter(x, y, duration, delay=0)
#
# [matplotlib API reference.](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html)

# %%
from IPython.display import Markdown, display
doc = plt.scatter.__doc__
display(Markdown(f"```\n{doc}\n```"))
# Out:
# ```
# A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
# Parameters
# ----------
# x, y : float or array-like, shape (n, )
#     The data positions.
#
# s : float or array-like, shape (n, ), optional
#     The marker size in points**2 (typographic points are 1/72 in.).
#     Default is ``rcParams['lines.markersize'] ** 2``.
#
#     The linewidth and edgecolor can visually interact with the marker
#     size, and can lead to artifacts if the marker size is smaller than
#     the linewidth.
#
#     If the linewidth is greater than 0 and the edgecolor is anything
#     but *'none'*, then the effective size of the marker will be
#     increased by half the linewidth because the stroke will be centered
#     on the edge of the shape.
#
#     To eliminate the marker edge either set *linewidth=0* or
#     *edgecolor='none'*.
#
# c : array-like or list of :mpltype:`color` or :mpltype:`color`, optional
#     The marker colors. Possible values:
#
# ...

# %% [markdown]
# ### spawn():

# %%
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
seq.animate(dpl.scatter(x=x,y=y,duration=100).spawn())
seq.save_video(path='../_static/scatter_spawn.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/scatter_spawn.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/scatter_spawn.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### despawn():

# %%
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
seq.animate(dpl.scatter(x=x,y=y,duration=100).despawn())
seq.save_video(path='../_static/scatter_despawn.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/scatter_despawn.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/scatter_despawn.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### show():

# %%
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
seq.animate(dpl.scatter(x=x,y=y,duration=100).show())
seq.save_video(path='../_static/scatter_show.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/scatter_show.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/scatter_show.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### hide():

# %%
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
seq.animate(dpl.scatter(x=x,y=y,duration=100).hide())
seq.save_video(path='../_static/scatter_hide.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/scatter_hide.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/scatter_hide.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### morph():

# %%
theta = np.linspace(0,2*np.pi,200)
r = 1 - 0.5*np.sin(theta*2)**2
x = np.cos(theta)*r
y = np.sin(theta)*r

r = 1 + 0.5*np.sin(theta*2)**2
new_x = np.cos(theta)*r
new_y = np.sin(theta)*r

seq = dpl.Sequence()
seq.animate(dpl.scatter(x=x,y=y,duration=100).morph(new_x=new_x,new_y=new_y))
seq.save_video(path='../_static/scatter_morph.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/scatter_morph.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/scatter_morph.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### demorph():
#
# ```{note}
# The `demorph` function should only be called after calling `morph`.
# ```

# %%
theta = np.linspace(0,2*np.pi,200)
r = 1 - 0.5*np.sin(theta*2)**2
x = np.cos(theta)*r
y = np.sin(theta)*r

r = 1 + 0.5*np.sin(theta*2)**2
new_x = np.cos(theta)*r
new_y = np.sin(theta)*r

seq = dpl.Sequence()
plot = dpl.scatter(x=x,y=y,duration=100).morph(new_x=new_x,new_y=new_y)
seq.animate(plot.demorph())
seq.save_video(path='../_static/scatter_demorph.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/scatter_demorph.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/scatter_demorph.mp4" type="video/mp4">
#             </video>
