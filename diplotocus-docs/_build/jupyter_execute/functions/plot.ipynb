# %% [markdown]
# # diplotocus.plot

# %%
import diplotocus as dpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## diplotocus.plot(x, y, duration, delay=0)
#
# [matplotlib API reference.](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
from IPython.display import Markdown, display
doc = plt.plot.__doc__
display(Markdown(f"```\n{doc}\n```"))
# Out:
# ```
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# >>> plot(x, y, 'go--', linewidth=2, markersize=12)
# ...

# %% [markdown]
# ### spawn():

# %%
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
seq.animate(dpl.plot(x=x,y=y,duration=100).spawn())
seq.save_video(path='../_static/plot_spawn.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/plot_spawn.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/plot_spawn.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### despawn():

# %%
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
seq.animate(dpl.plot(x=x,y=y,duration=100).despawn())
seq.save_video(path='../_static/plot_despawn.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/plot_despawn.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/plot_despawn.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### show():

# %%
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
seq.animate(dpl.plot(x=x,y=y,duration=100).show())
seq.save_video(path='../_static/plot_show.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/plot_show.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/plot_show.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### hide():

# %%
x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
seq.animate(dpl.plot(x=x,y=y,duration=100).hide())
seq.save_video(path='../_static/plot_hide.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/plot_hide.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/plot_hide.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### morph():

# %%
theta = np.linspace(0,2*np.pi,200)
r = 1 - 0.5*np.sin(theta*2)**2
x = np.cos(theta)*r
y = np.sin(theta)*r

r = 1 + 0.5*np.sin(theta*2)**2
new_x = np.cos(theta)*r
new_y = np.sin(theta)*r

seq = dpl.Sequence()
seq.animate(dpl.plot(x=x,y=y,duration=100).morph(new_x=new_x,new_y=new_y))
seq.save_video(path='../_static/plot_morph.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/plot_morph.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/plot_morph.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### demorph():
#
# ```{note}
# The `demorph` function should only be called after calling `morph`.
# ```

# %%
theta = np.linspace(0,2*np.pi,200)
r = 1 - 0.5*np.sin(theta*2)**2
x = np.cos(theta)*r
y = np.sin(theta)*r

r = 1 + 0.5*np.sin(theta*2)**2
new_x = np.cos(theta)*r
new_y = np.sin(theta)*r

seq = dpl.Sequence()
plot = dpl.plot(x=x,y=y,duration=100).morph(new_x=new_x,new_y=new_y)
seq.animate(plot.demorph())
seq.save_video(path='../_static/plot_demorph.mp4')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video ../_static/plot_demorph.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="../_static/plot_demorph.mp4" type="video/mp4">
#             </video>
