# %%
import diplotocus as dpl
import matplotlib.pyplot as plt
import numpy as np

def plot(ease,ease_str,lims=(-0.1,1.1)):
    fig,ax = plt.subplots(figsize=(6,5))
    ax.set_xlim(-0.1,1.1)
    ax.set_ylim(lims[0],lims[1])
    ax.set_axis_off()

    x = np.linspace(0,1,200)
    y = [ease.ease(el) for el in x]
    ax.plot(x,y,alpha=0.5)
    ax.text(0.1,0.8,ease_str)
    ax.text(0.1,0.3,'Linear',alpha=0.5)

    seq = dpl.Sequence(fig=fig,quiet=True)
    ease = dpl.plot(x=0,y=0.75,duration=200,c='k',marker='o',markersize=10,easing=ease)
    linear = dpl.plot(x=0,y=0.25,duration=200,c='k',marker='o',markersize=10,alpha=0.5)
    plot = dpl.plot(x=x,y=y,c='C0',duration=200).spawn()
    seq.plot((ease,linear))
    seq.animate((ease.morph(new_x=1,new_y=0.75),linear.morph(new_x=1,new_y=0.25),plot))
    seq.wait(25)
    seq.save_video(path='_static/{}.mp4'.format(ease_str),speed=4)

# %% [markdown]
# # Easing functions
#
# By default, all animations are rendered with a linear time progression. If your video has multiple steps, the transition between them will appear abrupt as you end one and start another. This can be fixed by using **easing functions**. Easing functions are mappings between *frame number* and a *time parameter*. For example, you might want to start your animations slowly, and end very fast; in this case you'd want to use a non-linear easing function.
#
# There are multiple ways to use an easing function in diplotocus. You can either set an easing for a whole *sequence*, an *animation* or a *plot function*. If multiple easings are set, the priority goes from the more specific to the more general, i.e. an easing set on a *plot function* will have priority over an easing set on an *animation*, which will have priority over an easing set on a *sequence*. For example, consider this code:

# %%
fig,ax = plt.subplots(figsize=(5,5))
ax.set_xlim(-0.1,1.1)
ax.set_ylim(-0.1,1.1)
ax.set_axis_off()

seq = dpl.Sequence(fig=fig,easing=dpl.easings.easeInOutQuart())

plot1 = dpl.plot(x=0,y=1,c='k',marker='o',markersize=10,duration=100)
plot2 = dpl.plot(x=0,y=0,c='k',marker='o',markersize=10,duration=100,easing=dpl.easings.easeCubicBezier(0,.84,.16,.54))

seq.animate((
        plot1.morph(new_x=1,new_y=1),
        plot2.morph(new_x=1,new_y=0)
    ),
    easing=dpl.easings.easeLinear()
)
seq.animate((
        plot1.demorph(),
        plot2.demorph()
    )
)

seq.save_video(path='_static/easeExample.mp4')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeExample.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# We set easing functions for our *sequence*, our first *animation* and our second *plot*. During the first animation, `plot1` gets the easing from the *animation* easing and `plot2` from its own easing. During the second animation, `plot1` gets its easing from the *sequence* easing and `plot2` still from its own easing.
#
# Here are all the easing functions implemented in diplotocus:

# %% [markdown]
# ## easeLinear():
#
# ```
#     f(x) = x
# ```

# %%
plot(dpl.easings.easeLinear(),'easeLinear')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeLinear.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Sine
# ### easeInSine:
#
# ```
#     f(x) = 1 - cos((x * π) / 2)
# ```

# %%
plot(dpl.easings.easeInSine(),'easeInSine')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInSine.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutSine():
#
# ```
#     f(x) = sin((x * π) / 2)
# ```

# %%
plot(dpl.easings.easeOutSine(),'easeOutSine')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutSine.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutSine():
#
# ```
#     f(x) = -(cos(π * x) - 1) / 2
# ```

# %%
plot(dpl.easings.easeInOutSine(),'easeInOutSine')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutSine.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Quadratic
# ### easeInQuad():
#
# ```
#     f(x) = x^2
# ```

# %%
plot(dpl.easings.easeInQuad(),'easeInQuad')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInQuad.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutQuad():
#
# ```
#     f(x) = 1 - (1 - x) * (1 - x)
# ```

# %%
plot(dpl.easings.easeOutQuad(),'easeOutQuad')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutQuad.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutQuad():
#
# ```
#     f(x) = x < 0.5 ? 2 * x^2 : 1 - (-2 * x + 2)^2 / 2
# ```

# %%
plot(dpl.easings.easeInOutQuad(),'easeInOutQuad')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutQuad.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Cubic
# ### easeInCubic():
#
# ```
#     f(x) = x^3
# ```

# %%
plot(dpl.easings.easeInCubic(),'easeInCubic')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInCubic.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutCubic():
#
# ```
#     f(x) = 1 - (1 - x)^3
# ```

# %%
plot(dpl.easings.easeOutCubic(),'easeOutCubic')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutCubic.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutCubic():
#
# ```
#     f(x) = x < 0.5 ? 4 * x^3 : 1 - (-2 * x + 2)^3 / 2
# ```

# %%
plot(dpl.easings.easeInOutCubic(),'easeInOutCubic')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutCubic.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Quartic
# ### easeInQuart():
#
# ```
#     f(x) = x^4
# ```

# %%
plot(dpl.easings.easeInQuart(),'easeInQuart')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInQuart.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutQuart():
#
# ```
#     f(x) = 1 - (1 - x)^4
# ```

# %%
plot(dpl.easings.easeOutQuart(),'easeOutQuart')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutQuart.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutQuart():
#
# ```
#     f(x) = x < 0.5 ? 8 * x^4 : 1 - (-2 * x + 2)^4 / 2
# ```

# %%
plot(dpl.easings.easeInOutQuart(),'easeInOutQuart')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutQuart.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Quintic
# ### easeInQuint():
#
# ```
#     f(x) = x^5
# ```

# %%
plot(dpl.easings.easeInQuint(),'easeInQuint')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInQuint.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutQuint():
#
# ```
#     f(x) = 1 - (1 - x)^5
# ```

# %%
plot(dpl.easings.easeOutQuint(),'easeOutQuint')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutQuint.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutQuint():
#
# ```
#     f(x) = x < 0.5 ? 16 * x^5 : 1 - (-2 * x + 2)^5 / 2
# ```

# %%
plot(dpl.easings.easeInOutQuint(),'easeInOutQuint')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutQuint.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Exponential
# ### easeInExpo():
#
# ```
#     f(x) = x === 0 ? 0 : 2^(10 * x - 10)
# ```

# %%
plot(dpl.easings.easeInExpo(),'easeInExpo')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInExpo.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutExpo():
#
# ```
#     f(x) = x === 1 ? 1 : 1 - 2^(-10 * x)
# ```

# %%
plot(dpl.easings.easeOutExpo(),'easeOutExpo')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutExpo.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutExpo():
#
# ```
#     f(x) = x === 0
#         ? 0
#         : x === 1
#         ? 1
#         : x < 0.5 ? Math.pow(2, 20 * x - 10) / 2
#         : (2 - Math.pow(2, -20 * x + 10)) / 2
# ```

# %%
plot(dpl.easings.easeInOutExpo(),'easeInOutExpo')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutExpo.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Circular
# ### easeInCirc():
#
# ```
#     f(x) = 1 - sqrt(1 - x^2)
# ```

# %%
plot(dpl.easings.easeInCirc(),'easeInCirc')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInCirc.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutCirc():
#
# ```
#     f(x) = sqrt(1 - (x - 1)^2)
# ```

# %%
plot(dpl.easings.easeOutCirc(),'easeOutCirc')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutCirc.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutCirc():
#
# ```
#     f(x) = x < 0.5
#         ? (1 - sqrt(1 - (2 * x)^2)) / 2
#         : (sqrt(1 - (-2 * x + 2)^2) + 1) / 2
# ```

# %%
plot(dpl.easings.easeInOutCirc(),'easeInOutCirc')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutCirc.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Back
# ### easeInBack():
#
# ```
#     c1 = 1.70158
#     c3 = c1 + 1
#
#     f(x) = c3 * x * x * x - c1 * x * x
# ```

# %%
plot(dpl.easings.easeInBack(),'easeInBack',lims=(-0.15,1.15))
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInBack.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutBack():
#
# ```
#     c1 = 1.70158
#     c3 = c1 + 1
#
#     f(x) = 1 + c3 * (x - 1)^3 + c1 * (x - 1)^2
# ```

# %%
plot(dpl.easings.easeOutBack(),'easeOutBack',lims=(-0.15,1.15))
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutBack.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutBack():
#
# ```
#     c1 = 1.70158
#     c2 = c1 * 1.525
#
#     f(x) = x < 0.5
#         ? ((2 * x)^2 * ((c2 + 1) * 2 * x - c2)) / 2
#         : ((2 * x - 2)^2 * ((c2 + 1) * (x * 2 - 2) + c2) + 2) / 2
# ```

# %%
plot(dpl.easings.easeInOutBack(),'easeInOutBack',lims=(-0.15,1.15))
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutBack.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Elastic
# ### easeInElastic():
#
# ```
#     c4 = (2 * π) / 3
#
#     f(x) = x === 0
#         ? 0
#         : x === 1
#         ? 1
#         : -2^(10 * x - 10) * sin((x * 10 - 10.75) * c4)
# ```

# %%
plot(dpl.easings.easeInElastic(),'easeInElastic',lims=(-0.4,1.1))
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInElastic.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutElastic():
#
# ```
#     c4 = (2 * π) / 3
#
#     f(x) = x === 0
#         ? 0
#         : x === 1
#         ? 1
#         : 2^(-10 * x) * sin((x * 10 - 0.75) * c4) + 1
# ```

# %%
plot(dpl.easings.easeOutElastic(),'easeOutElastic',lims=(-0.1,1.4))
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutElastic.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutElastic():
#
# ```
#     c4 = c5 = (2 * π) / 4.5
#
#     f(x) = x === 0
#         ? 0
#         : x === 1
#         ? 1
#         : x < 0.5
#         ? -(2^(20 * x - 10) * sin((20 * x - 11.125) * c5)) / 2
#         : (2^(-20 * x + 10) * sin((20 * x - 11.125) * c5)) / 2 + 1
# ```

# %%
plot(dpl.easings.easeInOutElastic(),'easeInOutElastic',lims=(-0.4,1.4))
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutElastic.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## Bounce
# ### easeInBounce():
#
# ```
#     f(x) = 1 - f_easeOutBounce(1 - x)
# ```

# %%
plot(dpl.easings.easeInBounce(),'easeInBounce')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInBounce.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeOutBounce():
#
# ```
#     n1 = 7.5625
#     d1 = 2.75
#
#     if (x < 1 / d1) {
#         f(x) = n1 * x * x
#     } else if (x < 2 / d1) {
#         f(x) = n1 * (x -= 1.5 / d1) * x + 0.75
#     } else if (x < 2.5 / d1) {
#         f(x) = n1 * (x -= 2.25 / d1) * x + 0.9375
#     } else {
#         f(x) = n1 * (x -= 2.625 / d1) * x + 0.984375
#     }
# ```

# %%
plot(dpl.easings.easeOutBounce(),'easeOutBounce')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeOutBounce.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ### easeInOutBounce():
#
# ```
#     f(x) = 1 - f_easeOutBounce(1 - x)
#     f(x) = x < 0.5
#         ? (1 - f_easeOutBounce(1 - 2 * x)) / 2
#         : (1 + f_easeOutBounce(2 * x - 1)) / 2
# ```

# %%
plot(dpl.easings.easeInOutBounce(),'easeInOutBounce')
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/easeInOutBounce.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## easeCubicBezier(x1,y1,x2,y2):
#
# This function lets you define a custom easing function, as a [cubic Bézier curve](https://en.wikipedia.org/wiki/B%C3%A9zier_curve#Cubic_B%C3%A9zier_curves). The implementation is similar to the CSS one, i.e. it is inverting the x(t)=t relation to find a y(t) solution, given the positions of the control points P1=(x1,y1) and P2=(x2,y2).
#
# ```{note}
# You can use [cubic-bezier.com](https://cubic-bezier.com) to find the right easing for you.
# ```

# %%
fig,ax = plt.subplots(figsize=(6,5))
ax.set_xlim(-0.1,1.1)
ax.set_ylim(-0.1,1.1)
ax.set_axis_off()

ease = dpl.easings.easeCubicBezier(.43,-0.5,.56,1.5)

x = np.linspace(0,1,100)
y = ease.ease(x)
ax.plot(x,y,alpha=0.5)
ax.text(0.1,0.8,'Cubic Bézier')
ax.text(0.1,0.3,'Linear',alpha=0.5)

seq = dpl.Sequence(fig=fig,quiet=True)
ease = dpl.plot(x=0,y=0.75,duration=200,c='k',marker='o',markersize=10,easing=ease)
linear = dpl.plot(x=0,y=0.25,duration=200,c='k',marker='o',markersize=10,alpha=0.5)
plot = dpl.plot(x=x,y=y,c='C0',duration=200).spawn()
seq.plot((ease,linear))
seq.animate((ease.morph(new_x=1,new_y=0.75),linear.morph(new_x=1,new_y=0.25),plot))
seq.wait(25)
seq.save_video(path='_static/cubicBezier.mp4',speed=4)
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/cubicBezier.mp4" type="video/mp4">
#             </video>

# %% [markdown]
# ## custom easing function:
# For more complicated easing functions than cubic Bézier curves, you can define your own by creating a child class of the `diplotocus.easings.Easing` class. All you have to do is define its `ease(self,x)` method so it returns a time parameter for a given linear time `x`. Here's an example:

# %%
class myEase(dpl.easings.Easing):
    def ease(self,x):
        if x < 0.75:
            return np.abs(np.sin(x*4/.75*np.pi))/(x*5+1)
        else:
            return ((x-.75)/.25)**2

# %%
fig,ax = plt.subplots(figsize=(6,5))
ax.set_xlim(-0.1,1.1)
ax.set_ylim(-0.1,1.1)
ax.set_axis_off()

ease = myEase()

x = np.linspace(0,1,200)
y = [ease.ease(el) for el in x]
ax.plot(x,y,alpha=0.5)
ax.text(0.1,0.8,'My Ease')
ax.text(0.1,0.3,'Linear',alpha=0.5)

seq = dpl.Sequence(fig=fig,quiet=True)
ease = dpl.plot(x=0,y=0.75,duration=200,c='k',marker='o',markersize=10,easing=ease)
linear = dpl.plot(x=0,y=0.25,duration=200,c='k',marker='o',markersize=10,alpha=0.5)
plot = dpl.plot(x=x,y=y,c='C0',duration=200).spawn()
seq.plot((ease,linear))
seq.animate((ease.morph(new_x=1,new_y=0.75),linear.morph(new_x=1,new_y=0.25),plot))
seq.wait(25)
seq.save_video(path='_static/customEase.mp4',speed=4)
# Out:
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/customEase.mp4" type="video/mp4">
#             </video>
