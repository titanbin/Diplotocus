# %% [markdown]
# # Welcome to diplotocus' documentation!
#
# <center><video width="700" height="394" autoplay muted playsinline><source src="_static/logo.mp4" type="video/mp4"></video></center>

# %% [markdown]
# **Diplotocus** is a python package designed to render animations of matplotlib plots, in a *timeline* style.
#
# Here's a quick example of the syntax of diplotocus:

# %%
import diplotocus as dpl
import numpy as np

x = np.linspace(0,6*np.pi,200)
y = np.cos(x)

seq = dpl.Sequence()
plot = dpl.plot(x=x,y=y,duration=100)
seq.animate(plot.spawn())
seq.wait(duration=25)
seq.animate((dpl.axis_zoom(zoom=0.5,duration=50),dpl.axis_move(pos=(0,0),duration=50)))
seq.animate(plot.hide())
seq.save_video(path='_static/test.mp4')
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Saved video _static/test.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/test.mp4" type="video/mp4">
#             </video>

# %%
import matplotlib.pyplot as plt
import diplotocus as dpl

styles = [
    {'fc': '#c96727','lw':0},
    {'fc': '#296618','lw':0},
    {'fc': '#3a7e28','lw':0},
    {'fc': '#26588f','ec': '#26588f','lw': 1.25}
]

svgs = [
    {'style':1-1, 'path':"M146.04,314.09c2.6-1.8-2.7-11.8-5.5-12.1-2.8-.3-9.4,10.3-6.9,12.1,2.4,1.8,9.9,1.8,12.4,0Z"},
    {'style':1-1, 'path':"M210.54,301.29c4.1-3.3-6.8-15-10.7-14.7s-7.7,14.5-6.3,18,12.8,0,17-3.3Z"},
    {'style':1-1, 'path':"M271.94,277.99c4.3-5-12.1-16.9-16.9-15.7-4.7,1.2-8.8,22.2-3.7,23.7,5.1,1.4,16.2-3,20.6-8Z"},
    {'style':1-1, 'path':"M328.14,233.39c2.9-7.4-15.9-15.1-21.9-13.6s-7,17.4-.9,26.8c6.1,9.5,19.9-5.8,22.8-13.2Z"},
    {'style':2-1, 'path':"M161.04,377.49c-7.2,3.8,8.2,18.3,14.7,18.3s18.5-19.4,12.5-22.1c-6.1-2.7-20,0-27.2,3.8Z"},
    {'style':2-1, 'path':"M393.64,368.59c0,9.5,10.5,23.8,15.3,23.8s16.7-80.9,8.5-74.5c-8.2,6.4-23.8,41.2-23.8,50.7Z"},
    {'style':3-1, 'path':"M423.64,43.29c-.9-13.5-8.9-29.2-26.1-23.5-17.1,5.7-46.4,18.4-43,35.3,3.4,16.9,39.1,10.3,35.5,41.9-1.3,19.1-4.1,209.5-258.9,223.8-45.7,3.2-15.6,75.1,6.4,75.1s-1.3-21.5,22.9-24.8c24.2-3.3,122.8-12.3,159.4-20.2,36.6-7.9,23.1,45,48.5,45,17.1,0,14.5-42.5,44-92.2,29.5-49.8,12-250.3,11.3-260.4Zm-31.1,2.5c-2.7,0-4.8-2.2-4.8-4.8s2.2-4.8,4.8-4.8,4.8,2.2,4.8,4.8-2.2,4.8-4.8,4.8Z"},
    {'style':4-1, 'path':"M451.14,440.99l1.3,.3,1.2,.2,1.1-.2h1.2l1.2-.2,1,.4,1.1,.3,.9,.3,1.8,.8,.8,.5,1.2,.3,1,1.3,.8,1.4,.7,1.3v1.3l-.8,1.8-.3,1.3-.7,1.1-.6,.8-.8,.3-1,.3-1.2,.4h-1.1l-1,.6-1.3-.4-1.1-.2-1.2-.9-.7-1.4v-1.1l.3-1.4,.4-1.2,.4-1-.9-.6-1.2-.3-1.4,.3-1.3,.2-1.3,.4-1.2,.4-.7,1-.9,.7-.4,.9-.2,1.4,.3,1.7,.8,1.3,.8,.8,1.1,.6,.7,1.2,1.2,.5,.9,1,1.1,.8,1.1,.3,.9,.8,.9,.6,2,1.3,1,.4,1.2,.7,1,.8,.9,.9,1.3,.8,1.3,1,.5,1.3,.7,1.3,.5,1.5,.2,1.6-.2,1.4-.5,1.3-.4,1.2-.5,.9-.3,.8-.8,.4-.8,.8-1,.4-.8,.7-1,.7-.5,1-1.6,.4-1.2,.6-1,.3-1.3,.2h-1.6l-1.6,.3-1.3-.2h-2.8l-1.1-.3-1.4-.3-1.3-.6h-1.4l-1.3-.6-1.1-.3-1.1-.8-1-.6-.6-.9-.7-1-.4-1.1-.4-.9,.1-1-.2-1,.2-.9,.6-.7,.3-.8,.7-.7,.6-.8,.7-.7,.4-.8,.8-.4,.8-.3,.8-.6,.8-.1,1.1-.2,.8,.3,.9,.2,.8,.4,1,.4,.7,.9,.4,1.2v1.3l.2,1.7-1,1.1-.7,.8,1.3,.8,1.7,.5,1.4-.5,1.6-.2,1.3-.5,1.3,.3,1.2-.2,.4-.8-.2-.8-.4-1.1-.7-1.3-.8-.9-1.2-.8-2.7-1.7-1.3-.7-1.2-.8-1-.9-1.5-.8-1-.8-1.3-.7-1.3-.8-.8-.8-1-.8-.8-1.1-.8-1.3-1.1-1.4-1.1-1.3-.8-1.2,.2-1-.3-1.1-.1-1.3,.3-1.2,.6-.9,.8-.9,.2-1,.8-.6,.9-.6,.4-.8,1.1-.5,.6-.5,.7-1,1.3-.4,1.3-.8,1.4-.5,1.8-.3,1.3-1,2.2-.7Z"}
]    

body = []
spikes = []
title = []

for i,svg in enumerate(svgs):
    svg_obj = dpl.svg(data=svg['path'],duration=100,**styles[svg['style']])
    if svg['style'] == 0:
        svg_obj = svg_obj.scale(scale_start=0,scale_end=1).set_delay(delay=i*35).set_duration(duration=30).set_easing(easing=dpl.easings.easeCubicBezier(.55,.42,.55,1.62))
        spikes.append(svg_obj)
    elif svg['style'] == 3:
        svg_obj = svg_obj.scale(scale_start=0,scale_end=1).set_delay(delay=i*5)
        title.append(svg_obj)
    else:
        body.append(svg_obj)

fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.set_xlim(0,510)
ax.set_ylim(510,0)

seq = dpl.Sequence(fig=fig,noaxis=True,dpi=300)

seq.plot(body)
seq.animate(spikes + title,easing=dpl.easings.easeOutBack())
seq.save_video(path='_static/logo.mp4',speed=4)
# Out:
#   0%|          | 0/180 [00:00<?, ?it/s]
# Saved video _static/logo.mp4
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="_static/logo.mp4" type="video/mp4">
#             </video>

# %%
import diplotocus as dpl
import numpy as np

seq = dpl.Sequence(name='ee',transparent=True,white=True)

x = np.linspace(0,10,1000)
y = np.cos(x)
plot = dpl.plot(x=x,y=y) \
    .translate((0,0),(40,40),duration=500) \
    .scale(1,6,duration=500) \
    .tweens(('c','alpha','lw'),('C1',0.25,1),('C2',1,10),duration=500)

path = "M43.3,2l41.57,72H1.73L43.3,2m0-2L0,75H86.6L43.3,0h0Z"
svg = dpl.svg(path,'r').rotate(0,360,duration=500).scale(1,0.25,duration=500)

axis_move = dpl.axis_move((60,60),duration=50,delay=50)
axis_zoom = dpl.axis_zoom(0.75,duration=50,delay=50)

seq.animate([plot,svg,axis_move])
seq.wait(50)
seq.animate(axis_zoom)
seq.save_video('test.mov',clean=False)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# Saved video test.mov
# [concat @ 0x960c5c000] Impossible to open 'ee/ee_549.png'
# [in#0/concat @ 0x96101c000] Error during demuxing: No such file or directory
#             <video width="640" height="360" autoplay loop muted playsinline>
#             <source src="test.mov" type="video/mp4">
#             </video>

# %%
import diplotocus as dpl
import numpy as np

seq = dpl.Sequence()

x = np.linspace(0,10,1000)
y = np.cos(x)
plot = dpl.plot(x=x,y=y,duration=100).translate((40,40)).scale(1,6).tweens(('c','alpha','lw'),('C1',0.25,1),('C2',1,10))

path = "M43.3,2l41.57,72H1.73L43.3,2m0-2L0,75H86.6L43.3,0h0Z"
svg = dpl.svg(path,'r',duration=50,delay=25).rotate(0,360).scale(1,0.25)

seq.animate([plot,svg])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
import diplotocus as dpl
import numpy as np

x = np.linspace(0,10,100)
y = np.cos(x)
x2 = np.linspace(0,10,100)
y2 = np.sin(x2)
x2 = np.cos(x2)*2 + 5

a = dpl.plot(x=x,y=y)#,marker='.',facecolor='r',edgecolor='g',s=100)
#a = a.translate(duration=120,delay=36,start_pos=(0,0),end_pos=(1,1))
#a = a.rotate(duration=120,delay=36,angle_start=0,angle_end=360)
#a = a.scale(duration=120,delay=36,scale_start=1,scale_end=0.2)
a = a.morph(new_x=x2,new_y=y2,duration=100)
seq = dpl.Sequence(transparent=True,white=True)
seq.plot(a,x=50)
#seq.save_video('test.mov')

# %%
import ast

x = '[ "A","B","C" , " D",2,1.0]'

type(ast.literal_eval(x)[-1])
# Out:
# float

# %%
import matplotlib as mpl

mpl.colors.to_rgba_array('C1')[0]
# Out:
# array([1.        , 0.49803922, 0.05490196, 1.        ])

# %%
from matplotlib.lines import Line2D
import inspect
import matplotlib.pyplot as plt

obj = plt.hist
par = type(obj([1,])[2][0])

sig = inspect.signature(obj)
kwargs = [
    param.name for param in sig.parameters.values() if
    (param.kind == param.KEYWORD_ONLY or param.kind == param.VAR_KEYWORD or param.default != param.empty)
    and param.name != 'kwargs']
print(kwargs)

sig = inspect.signature(par)
kwargs = [
    param.name for param in sig.parameters.values() if
    (param.kind == param.KEYWORD_ONLY or param.kind == param.VAR_KEYWORD or param.default != param.empty)
    and param.name != 'kwargs']
print(kwargs)
# Out:
# ['bins', 'range', 'density', 'weights', 'cumulative', 'bottom', 'histtype', 'align', 'orientation', 'rwidth', 'log', 'color', 'label', 'stacked', 'data']
# ['angle', 'rotation_point']
